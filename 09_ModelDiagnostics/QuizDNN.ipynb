# %% [markdown]
# <a href="https://colab.research.google.com/github/satyajitghana/TSAI-DeepVision-EVA4.0/blob/master/09_ModelDiagnostics/QuizDNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Quiz Model

# %%
from datetime import datetime
print("Current Date/Time: ", datetime.now())
# Out:
# Current Date/Time:  2020-03-17 21:51:09.924942

# %% [markdown]
# ## Install the PySodium Library

# %%
# !pip install --upgrade --no-deps --force-reinstall git+https://github.com/satyajitghana/PySodium.git#egg=sodium
# Out:
# Collecting sodium
#   Cloning https://github.com/satyajitghana/PySodium.git to /tmp/pip-install-5ojj7xg6/sodium
#   Running command git clone -q https://github.com/satyajitghana/PySodium.git /tmp/pip-install-5ojj7xg6/sodium
# Building wheels for collected packages: sodium
#   Building wheel for sodium (setup.py) ... done
#   Created wheel for sodium: filename=sodium-0.0.1-cp36-none-any.whl size=17503 sha256=8c07238587276681780e4101fd6ce5c2c8c7d8b9b387e9c50d02330d0e95901d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-s7es3ccb/wheels/ed/b2/24/860b8aa92c98c5b8e1e724d604e3c4bf4039ab8bb7f66bcc82
# Successfully built sodium
# Installing collected packages: sodium
#   Found existing installation: sodium 0.0.1
#     Uninstalling sodium-0.0.1:
#       Successfully uninstalled sodium-0.0.1
# Successfully installed sodium-0.0.1

# %% [markdown]
# ## Create a config file

# %%
# %%writefile quiz.yml
# name: QuizModel
# save_dir: saved/
# seed: 1
# target_device: 0
#
# arch:
#     type: QuizDNNModel
#     args: {}
#
# augmentation:
#     type: CIFAR10Albumentations
#     args: {}
#
# data_loader:
#     type: CIFAR10DataLoader
#     args:
#         batch_size: 512
#         data_dir: data/
#         nworkers: 4
#         shuffle: True
#
# criterion: cross_entropy_loss
#
# lr_scheduler:
#     type: OneCycleLR
#     args:
#         max_lr: 0.5
#
# optimizer:
#     type: SGD
#     args:
#         lr: 0.001
#         momentum: 0.95
#         weight_decay: 0.0005
#
# training:
#     epochs: 20
# Out:
# Overwriting quiz.yml

# %% [markdown]
# ## Import sodium

# %%
from sodium.utils import load_config
import sodium.runner as runner

# %% [markdown]
# ## Create a runner with the config and train the model

# %%
config = load_config('quiz.yml')
runner = runner.Runner(config)
runner.train(tsai_mode=True)
# Out:
# [ 2020-03-17 22:48:41,379 - sodium.sodium.runner ] INFO: Training: {'name': 'QuizModel', 'save_dir': 'saved/', 'seed': 1, 'target_device': 0, 'arch': {'type': 'QuizDNNModel', 'args': {}}, 'augmentation': {'type': 'CIFAR10Albumentations', 'args': {}}, 'data_loader': {'type': 'CIFAR10DataLoader', 'args': {'batch_size': 512, 'data_dir': 'data/', 'nworkers': 4, 'shuffle': True}}, 'criterion': 'cross_entropy_loss', 'lr_scheduler': {'type': 'OneCycleLR', 'args': {'max_lr': 0.5}}, 'optimizer': {'type': 'SGD', 'args': {'lr': 0.001, 'momentum': 0.95, 'weight_decay': 0.0005}}, 'training': {'epochs': 20}}
# [ 2020-03-17 22:48:41,381 - sodium.sodium.utils.config ] INFO: Building: sodium.tsai_model.QuizDNNModel
# [ 2020-03-17 22:48:41,392 - sodium.sodium.utils.config ] INFO: Using device 0 of available devices [0]
# [ 2020-03-17 22:48:41,397 - sodium.sodium.utils.config ] INFO: Building: torch.optim.SGD
# [ 2020-03-17 22:48:41,398 - sodium.sodium.utils.config ] INFO: Building: sodium.data_loader.augmentation.CIFAR10Albumentations
# [ 2020-03-17 22:48:41,400 - sodium.sodium.utils.config ] INFO: Building: sodium.data_loader.data_loaders.CIFAR10DataLoader
# Files already downloaded and verified
# Files already downloaded and verified
# [ 2020-03-17 22:48:43,138 - sodium.sodium.runner ] INFO: Building: torch.optim.lr_scheduler.OneCycleLR
# [ 2020-03-17 22:48:43,139 - sodium.sodium.runner ] INFO: Getting loss function handle
# [ 2020-03-17 22:48:43,140 - sodium.sodium.runner ] INFO: Initializing trainer
# [ 2020-03-17 22:48:43,142 - sodium.sodium.base.base_trainer ] INFO: Starting training ...
# [ 2020-03-17 22:48:43,144 - sodium.sodium.base.base_trainer ] INFO: Training the model for 20 epochs
#
# Training Epoch: 1
# HBox(children=(IntProgress(value=0, layout=Layout(flex='2'), max=98), HTML(value='')), layout=Layout(display='…
# Testing Epoch: 1
# Test Set: Average Loss: 2.40666883, Accuracy: 23.94 (2394/10000)
#
# Training Epoch: 2
# HBox(children=(IntProgress(value=0, layout=Layout(flex='2'), max=98), HTML(value='')), layout=Layout(display='…
# Testing Epoch: 2
# Test Set: Average Loss: 1.56750012, Accuracy: 42.87 (4287/10000)
#
# Training Epoch: 3
# HBox(children=(IntProgress(value=0, layout=Layout(flex='2'), max=98), HTML(value='')), layout=Layout(display='…
# Testing Epoch: 3
# Test Set: Average Loss: 1.65060592, Accuracy: 39.75 (3975/10000)
#
# Training Epoch: 4
# HBox(children=(IntProgress(value=0, layout=Layout(flex='2'), max=98), HTML(value='')), layout=Layout(display='…
# Testing Epoch: 4
# Test Set: Average Loss: 1.49460331, Accuracy: 45.39 (4539/10000)
#
# Training Epoch: 5
# HBox(children=(IntProgress(value=0, layout=Layout(flex='2'), max=98), HTML(value='')), layout=Layout(display='…
# Testing Epoch: 5
# Test Set: Average Loss: 1.49042417, Accuracy: 48.06 (4806/10000)
#
# Training Epoch: 6
# HBox(children=(IntProgress(value=0, layout=Layout(flex='2'), max=98), HTML(value='')), layout=Layout(display='…
# Testing Epoch: 6
# Test Set: Average Loss: 1.38823916, Accuracy: 51.07 (5107/10000)
#
# Training Epoch: 7
# HBox(children=(IntProgress(value=0, layout=Layout(flex='2'), max=98), HTML(value='')), layout=Layout(display='…
# Testing Epoch: 7
# Test Set: Average Loss: 1.07798655, Accuracy: 61.03 (6103/10000)
#
# Training Epoch: 8
# HBox(children=(IntProgress(value=0, layout=Layout(flex='2'), max=98), HTML(value='')), layout=Layout(display='…
# Testing Epoch: 8
# Test Set: Average Loss: 1.09065518, Accuracy: 61.01 (6101/10000)
#
# Training Epoch: 9
# HBox(children=(IntProgress(value=0, layout=Layout(flex='2'), max=98), HTML(value='')), layout=Layout(display='…
# Testing Epoch: 9
# Test Set: Average Loss: 1.02254097, Accuracy: 64.96 (6496/10000)
#
# Training Epoch: 10
# HBox(children=(IntProgress(value=0, layout=Layout(flex='2'), max=98), HTML(value='')), layout=Layout(display='…
# Testing Epoch: 10
# Test Set: Average Loss: 1.10872939, Accuracy: 61.14 (6114/10000)
#
# Training Epoch: 11
# HBox(children=(IntProgress(value=0, layout=Layout(flex='2'), max=98), HTML(value='')), layout=Layout(display='…
# Testing Epoch: 11
# Test Set: Average Loss: 1.08396004, Accuracy: 63.13 (6313/10000)
#
# Training Epoch: 12
# HBox(children=(IntProgress(value=0, layout=Layout(flex='2'), max=98), HTML(value='')), layout=Layout(display='…
# Testing Epoch: 12
# Test Set: Average Loss: 0.97930990, Accuracy: 65.70 (6570/10000)
#
# Training Epoch: 13
# HBox(children=(IntProgress(value=0, layout=Layout(flex='2'), max=98), HTML(value='')), layout=Layout(display='…
# Testing Epoch: 13
# Test Set: Average Loss: 0.94548505, Accuracy: 66.79 (6679/10000)
#
# Training Epoch: 14
# HBox(children=(IntProgress(value=0, layout=Layout(flex='2'), max=98), HTML(value='')), layout=Layout(display='…
# Testing Epoch: 14
# Test Set: Average Loss: 0.85767828, Accuracy: 69.38 (6938/10000)
#
# Training Epoch: 15
# HBox(children=(IntProgress(value=0, layout=Layout(flex='2'), max=98), HTML(value='')), layout=Layout(display='…
# Testing Epoch: 15
# Test Set: Average Loss: 0.83901199, Accuracy: 70.30 (7030/10000)
#
# Training Epoch: 16
# HBox(children=(IntProgress(value=0, layout=Layout(flex='2'), max=98), HTML(value='')), layout=Layout(display='…
# Testing Epoch: 16
# Test Set: Average Loss: 0.82722024, Accuracy: 70.88 (7088/10000)
#
# Training Epoch: 17
# HBox(children=(IntProgress(value=0, layout=Layout(flex='2'), max=98), HTML(value='')), layout=Layout(display='…
# Testing Epoch: 17
# Test Set: Average Loss: 0.71184922, Accuracy: 75.15 (7515/10000)
#
# Training Epoch: 18
# HBox(children=(IntProgress(value=0, layout=Layout(flex='2'), max=98), HTML(value='')), layout=Layout(display='…
# Testing Epoch: 18
# Test Set: Average Loss: 0.65841066, Accuracy: 77.01 (7701/10000)
#
# Training Epoch: 19
# HBox(children=(IntProgress(value=0, layout=Layout(flex='2'), max=98), HTML(value='')), layout=Layout(display='…
# Testing Epoch: 19
# Test Set: Average Loss: 0.60771554, Accuracy: 78.52 (7852/10000)
#
# Training Epoch: 20
# HBox(children=(IntProgress(value=0, layout=Layout(flex='2'), max=98), HTML(value='')), layout=Layout(display='…
# Testing Epoch: 20
# Test Set: Average Loss: 0.59366392, Accuracy: 79.14 (7914/10000)
# [ 2020-03-17 22:54:56,095 - sodium.sodium.runner ] INFO: Finished!

# %% [markdown]
# ## Plot the metrics

# %%
runner.plot()
# Out:
# [ 2020-03-17 22:55:06,394 - sodium.sodium.runner ] INFO: Plotting Metrics...
